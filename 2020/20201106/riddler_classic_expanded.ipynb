# %% [markdown]
# ### Realized An Issue
#
# My process in the riddler_class notebook in this directory is missing a few scenarios that don't have real solutions.
#
# Here is how I am thinking about it:
#
# ### Flips at N = 3:
#
# - HHH (`p^3`)
# - HHT (`p^2 * (1-p)`)
# - HTT (`p * (1-p)^2`)
# - HTH (`p^2 * (1-p)`)
# - TTH (`p * |(1-p)^2`)
# - THH (`p^2 * (1-p)`)
# - THT (`p * (1-p)^2`)
# - TTT (`(1-p)^3`)
#
# There are 4 distinct strategies:
# - (`p^3`)         ---> Max case: We accept any tails, otherwise flip to `N = 3`
# - (`(1-p)^3`)     ---> Min case: We accept any heads, otherwise flip to `N = 3`
# - (`p^2 * (1-p)`) ---> No real solution?
# - (`p * (1-p)^2`) ---> No real solution?
#
# There are 4 distinct strategies:
# - (`p^3`)         ---> Max case: We accept any tails, otherwise flip to `N = 3`
#     - e.g.: If our first flip is `H`, we flip again. If its `T`, we keep it
# - (`(1-p)^3`)     ---> Min case: We accept any heads, otherwise flip to `N = 3`
#     - e.g.: If our first flip is `T`, we flip again. If its `H`, we keep it
# - (`p^2 * (1-p)`) ---> Real solution requires p < 0, or complex solutions
# - (`p * (1-p)^2`) ---> Real solution requires p > 1, or complex solution
#
#
# ### Flips at N = 2:
#
# - HH (`p^2`)
# - HT (`p * (1-p)`)
# - TH (`p * (1-p)`)
# - TTT (`(1-p)^2`)
#
# There are 3 distinct strategies:
# - (`p^2`)         ---> Max case: We accept any tails, otherwise flip to `N = 2`
# - (`(1-p)^2`)     ---> Min case: We accept any heads, otherwise flip to `N = 2`
# - (`p * (1-p)`) ---> No real solution
#
# ### Flips at N = 1:
# - H (`p`)
# - T (`(1-p)`)
#
# There are 2 distinct distinct strategies which yield the same value:
# - `p` = `1-p` = 0.5
#
#
# ### Final Real Solutions:
#
# Up to 3 flips:
# - `p` = 0.7937
# - `p` = 0.2063
#
# Up to 2 flips:
# - `p` = 0.707
# - `p` = 0.2929
#
# 1 flip & stop:
# - `p` = 0.5
